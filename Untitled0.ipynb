# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
y_test_encoded = to_categorical(le.fit_transform())
y_encoded = pd.DataFrame(y_test_encoded)
print(y_encoded)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-fdd06f3e26ba> in <module>()
#       1 le = LabelEncoder()
# ----> 2 y_test_encoded = to_categorical(le.fit_transform(["paris", "paris", "tokyo", "amsterdam"]))
#       3 y_encoded = pd.DataFrame(y_test_encoded)
#       4 print(y_encoded)
#
# NameError: name 'to_categorical' is not defined
